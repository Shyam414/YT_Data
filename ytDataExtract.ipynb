# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# %%
api_key = input("Please enter your YouTube Data API key: ")
channel_ids=['UCX6OQ3DkcsbYNE6H8uQQuVA',
             'UCChmJrVa8kDg05JfCmxpLRw',
             'UCkX0NXCP9kCLtk30kjTXIWg',
             'UCXqJrBG563pZnaqLoxHjUDg',
             'UCHoLIMtg_OigNlJmjHX9J8Q',
             'UCMOLiZpKXp-w5CNfqJObQUw',
             'UCtAXJ4DNpshfVjLIMq9pIRw']

youtube= build('youtube','v3',developerKey=api_key)

# %%
def get_channel(youtube,channel_ids):
    
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids)
                )
    response = request.execute() 
    

    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
channel_stats=get_channel(youtube,channel_ids)
channel_stats
# Out:
#          channelName subscribers        views totalVideos  \
# 0  Rohit & Kanupriya     2290000   2191409562         330
# 1   Something_beyond          18         8548          46
# 2            MrBeast   258000000  48773467167         794
# 3              KALEO     1950000   1553977588          68
# 4            coder2j       10000       929307          48
# 5          KEEMOKAZI     9780000  10671266154        1340
# 6     Darshil Parmar      130000      6007591         150
#
#                  playlistId
# 0  UUtAXJ4DNpshfVjLIMq9pIRw
# 1  UUkX0NXCP9kCLtk30kjTXIWg
# 2  UUX6OQ3DkcsbYNE6H8uQQuVA
# 3  UUXqJrBG563pZnaqLoxHjUDg
# 4  UUHoLIMtg_OigNlJmjHX9J8Q
# 5  UUMOLiZpKXp-w5CNfqJObQUw
# 6  UUChmJrVa8kDg05JfCmxpLRw

# %%
playlistid=channel_stats['playlistId']
playlistid
# Out:
# 0    UUtAXJ4DNpshfVjLIMq9pIRw
# 1    UUkX0NXCP9kCLtk30kjTXIWg
# 2    UUX6OQ3DkcsbYNE6H8uQQuVA
# 3    UUXqJrBG563pZnaqLoxHjUDg
# 4    UUHoLIMtg_OigNlJmjHX9J8Q
# 5    UUMOLiZpKXp-w5CNfqJObQUw
# 6    UUChmJrVa8kDg05JfCmxpLRw
# Name: playlistId, dtype: object

# %%
def get_video_ids(youtube, playlist_id,video_ids):

    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = []
for i in range(len(playlistid)):
    playlist_id=playlistid[i]
    Video_ids=get_video_ids(youtube, playlist_id,video_ids)
    
Video_ids
# Out:
# ['Fj-g-cmSzbo',
#  'JXvx90MmuG8',
#  '9ay_GsacYWs',
#  '-hPbCw8XzkQ',
#  'yXoqz_GOJxw',
#  'QGP02UnMhhE',
#  'ScnDAe0IsYc',
#  'UdrlseaiS2E',
#  '2WCcSLE7aDA',
#  'NeEFmzqU4bw',
#  'Lx1K81l6jp8',
#  'mpjSOp1ony0',
#  'Q5umEv8REXE',
#  'Psjl7R9PvKk',
#  'S03fsk2xEU0',
#  'Ncq5YpEDVZ0',
#  'aTdiqai6svU',
#  'jsSeYu9zIdc',
#  '9jNLpLgpJlY',
#  'nr4KL7tRmys',
#  'TjQyM_neV98',
#  'LntHPdRBSqA',
#  'jxkA8KVOiHU',
#  'We5OK72mVeg',
#  'tq1OE2yzZTk',
#  'yrRCaRMOhHE',
#  'IE2Ew9xMmZc',
#  'eDweuCINqvI',
#  'ssmLPVZhEVc',
#  'Uc7EHRY754M',
#  'atsKsG7pyUI',
#  'euBCf1Vc8Hs',
#  'jFPQr3iV3v8',
#  'nM4LTKhRQbM',
#  '8j_BsAKh1so',
#  'pXKXfAYH38Y',
#  'i0co3r6Z0ns',
#  'KW9ML8QTJlk',
#  'f7sWGZ81rPw',
#  'd6K_gHzi4HM',
#  'GeK9lfskd0U',
#  '1IJjXA_PpSs',
#  'YvHFC3ag1es',
#  '-s1uihIv2sU',
#  'IN4Gftz6_ZM',
#  '1bGdX8F47LA',
#  'xfAThv2Gfmg',
#  'xpfBmjZneoM',
#  'FNBaqQF5Xms',
#  'iefzOFm8aA0',
#  'gEozPeVocO0',
#  '2H3cGBCBO-U',
#  '1wF7cgH3yfc',
#  '7mfq-6CJdME',
#  'GQPtwHrIO2o',
#  'sq2-OHoP9SQ',
#  'hroZxA-5-Pg',
#  'tofVgA04smw',
#  'UCiBkTTG-48',
#  'HGAOyuf0HmU',
#  'mjVuMrgbIXU',
#  'RiDxl83cuss',
#  '_zsTu8_QGz8',
#  '2LgiXoWfwVw',
#  'd95wLM3a3C0',
#  'Q6AP_TjWKXw',
#  'ZkvnFpNUOfY',
#  'P1qLNi3W6G0',
#  'xPqgwKUsxKs',
#  'sP4v68KNLXI',
#  'XDpm0pon4J4',
#  '-X-Xqlx2r44',
#  'pXkW_LEdEAE',
#  'EiFsqP_M_NA',
#  'ca-m6Gh7y3Q',
#  'Vxg1HMUkeA8',
#  '35_PNN2CUOM',
#  'EQLkky_DoyY',
#  'hMdL0cnbmwk',
#  '0BoiGy2nHzQ',
#  'tgxFJl_YRZE',
#  'TUGtKR3zBBw',
#  'xj2Qy6_JBaw',
#  'Yrc9H0PN8kI',
#  'VKIKT6cd6RY',
#  'ub2MWi50iSk',
#  'oCy65GQ0pJY',
#  'e7HkbI6aTcY',
#  'IaJKrQaILcQ',
#  'oC8JniB4o30',
#  'kL41ZY6UMqg',
#  '3BuvAg-lnhs',
#  '1W-tsxmvuWk',
#  'yN7ACwFmys0',
#  'cN-oqSqpCEY',
#  'vut2EQ3OymA',
#  'ma2oslwBO-A',
#  'DPQU6hJCX3M',
#  'U_kXonzcw1U',
#  'woMJGI_6qZE',
#  'nNneNgi_Qi8',
#  'kbIIWsL3L98',
#  'khvsSbgyeas',
#  'GyySXbB7Jz0',
#  '4O2Ky_mXP2Q',
#  'hIvU9_eph0c',
#  'Y3P_Eg8LqqQ',
#  'vU6sfKZicG0',
#  'RFYbbhYOGsU',
#  'pTeukCISW1k',
#  'q_cPqFAX5qQ',
#  'OaWM5TR9gmo',
#  'uR_Lf4r5Dfc',
#  '5xXNKQxWTss',
#  '2gkC1PuDAWs',
#  'Z9zXrIfO_ZI',
#  '67NUYM1v4rM',
#  'cYhR6LJTUgk',
#  'bta4ike_yxI',
#  'Lai6yrvAhZk',
#  'IRTheDn-ZuE',
#  'cqIhi_9hcP0',
#  'fj1JRwsaV94',
#  'w8-CsMCSTbE',
#  'Nav72p0hI3E',
#  's4Zmspb-_IY',
#  'SQYfdsQk8xo',
#  'yCHIj22Yd-s',
#  'bDO-Kdhm3dE',
#  'zL7J79NBfNA',
#  'wRfq0eDUkyI',
#  'hLwQvbKASpw',
#  '6K9zOeS8ly4',
#  'QVZazzWWNiI',
#  'O8d9jElBVs4',
#  'UDFMm2Xm5EA',
#  'kohrnCNR3d8',
#  'tG83zY6h4-M',
#  'VUBdJxoveXI',
#  'FLHLxHsaiI8',
#  'xcmkWOa9NzI',
#  'wWf3yJgDACg',
#  'DbSpxab7bb0',
#  'KeAJnHK3uXk',
#  'wzXm2HJazSo',
#  'q7Hx6_8WuFQ',
#  '2mQxA2m63wY',
#  'F_nAOwYQmjc',
#  'mKBG3JZBR5Q',
#  '92qAEnpazGo',
#  'jAG4xf0Bciw',
#  'RAWv104XH2c',
#  'oZnCHCxtztI',
#  '-14x-LfhmZc',
#  'GHr62YvDSSs',
#  'aNnzjVbxX7c',
#  'HOpKn65ShDE',
#  'pAIqqtlcyns',
#  '8ivL3CLB_lM',
#  'wV-i617qwE8',
#  'yUpy88eOMuo',
#  'lL9gzAJIy8I',
#  'r83_IRU56x0',
#  'gDdAQrglj6o',
#  'S--HBKazoNM',
#  'erLG7o2QWZE',
#  'b8qDbZN5pIw',
#  '5PR-IEymKIk',
#  '__7FVToPEuE',
#  'IxrHMDLFn3U',
#  'JOpPSHGYP3o',
#  'j4WpqWtZ1eo',
#  'OcCAxTt8omY',
#  'fQCZLrXYpNs',
#  'XQJcvMG0faw',
#  'xMccWPqN948',
#  'jMB-RHci5Nk',
#  'u2dm90Xg3Bw',
#  'qQ4kgJWkzDc',
#  'ICWR1V7W4vU',
#  '4m5ocEhAttQ',
#  'MXje888GSgs',
#  'W4hWH7skDgo',
#  'f0r6LEpOTAI',
#  'P-S6gWNPgzM',
#  '9xn4URzsTz4',
#  'VwFAszveK1w',
#  'iuqsfAibyE8',
#  'VMHx4m_svgs',
#  'cWEG3KA7Ef8',
#  'lQhpsnuGRQo',
#  's-jGWn_h3Ls',
#  '2vNWAVeweio',
#  'iwK1-2AAjeM',
#  'qTzRPTKcpMI',
#  'yaDG61HrH5g',
#  'q6iKzeLhhao',
#  '9PTtbPF6W_0',
#  'xfysFqD9AAE',
#  'eyA4Vyw_Rtk',
#  'JXPGpBhu4Gc',
#  '6lJDwHC917s',
#  'ODxGkIsJRtA',
#  '3-ZdA4d5Rhc',
#  'SQk2lCrU4Vc',
#  'R8Z1ybsSed4',
#  'jiusV4_jF_8',
#  'jk_UfI0deic',
#  'IlDqirZQ01w',
#  'wUE0TvEtJ8g',
#  'N2EMwoiU4X4',
#  'my4vJB8sd94',
#  '7MDsEfHTFAk',
#  '3LbW_fqr0J0',
#  'nsYB37beNxw',
#  'Fh0nVTdy8O8',
#  '27gulhaf_LY',
#  'uFCE5DurE8c',
#  'FMOFiT-nL4E',
#  'lvcLbaxsQpY',
#  'ArPcM501q9s',
#  'Z5AcZ9PP2TE',
#  'ewzO8WIkmkI',
#  'sdtG7GCYczc',
#  'sZO05r1_Tfg',
#  'ljrIUXmbVnY',
#  'hvHMS1-kJPs',
#  '49wCxewpUdc',
#  'NwYaVfyLktY',
#  'sZWGz0-dtDw',
#  'plkICuisBFU',
#  'hoaDes6WSig',
#  'jiEc6LsTi6I',
#  'B0tDb4oSmZQ',
#  '1tK7pg4Rh7o',
#  '8bAXASiOkpo',
#  'UicXqdiVUrA',
#  'gYLvCmXAgA0',
#  'mTrj2BAdLi8',
#  'pcC8rWrQzFY',
#  '1Zbus7JYqqw',
#  'aWlgcsMvKbU',
#  'q9GX5_97x7o',
#  '7Vp7ZZB13qI',
#  'q6wvSL4Q6oU',
#  'oZcKB85nuG4',
#  'sARaQvUmz-U',
#  'IEDDeH1lZdE',
#  'xUVysSp9B8Q',
#  'pnhbgPML6xQ',
#  'iVF8_DTUpps',
#  'S0RhcrG8oJE',
#  'n9r2-I5ZerM',
#  '5oNGzF69two',
#  '4BnIrhFfhfo',
#  'jlYp61RVtEM',
#  'JNGMfT65vxA',
#  'ZIzgrk7c6-g',
#  'rz3zpVgGicQ',
#  'DHwVsP4IUeQ',
#  'Oqq_wWh-gw0',
#  'VhCwiW8LFuE',
#  'QpdCrHHSX-s',
#  '1eJtxSS9B0g',
#  'N-5xkSOFyQ0',
#  '9kut_N8r_Z8',
#  'uGfM3h1kzFQ',
#  'O0B5I0CrCX8',
#  'dROXWykSazc',
#  'j3fYkvTghsg',
#  'jVbQbMz3i5w',
#  'cR9bu8frSb8',
#  'JoINYZzoxj0',
#  'jsBaOYKAkZo',
#  'HloJ-aZFpVk',
#  '2xoUn3yC1Bo',
#  '2D8adwIjm74',
#  'Svr6fXtpjM4',
#  'ROBXLXGv1EM',
#  'b4uAvqQ1nnQ',
#  'TNplT0BfYW8',
#  '9HAOg1PDF08',
#  '9FvSsB8dUdU',
#  'y2s2Tc8ABxA',
#  '_bPEBqMappY',
#  'OcHg7-xE4yE',
#  'OCS_VFXn7c4',
#  'I6rfI0XnYAs',
#  '4y48zGfmPNM',
#  '8CIeMy5txGg',
#  'XxwTHJZH0Kw',
#  'ceOsIw4oYLI',
#  'vnu9Ebz_GCw',
#  'Zkqz0n5Skog',
#  'vOE5CLwQNoM',
#  'GKudefzpaxw',
#  'won-0djwveU',
#  'zwCTHj_yo7E',
#  'y0D_3R79UrU',
#  'nE1j6L1ER20',
#  'wmVz6tugnVk',
#  'Z7WFYzYhJYQ',
#  'dCxoQTmoMfg',
#  'fmJHK_dEy2Y',
#  'Rd0PPKdrrcI',
#  'D85ioCIr1q0',
#  'g4sDbTihD3w',
#  '8opALo2sGLE',
#  'CqzjHjOqoYA',
#  'rTev031xNFk',
#  'L0jlFztUwdo',
#  '98uJQyskCyw',
#  'rCoq1PLC-9Q',
#  'FMzMJjwxm7s',
#  '94PZ_iJKhaI',
#  'le3Uxg4hXjY',
#  'JMphmxXYLCc',
#  'K31Y4rsx5SA',
#  'sGBqBdsPiEg',
#  'huIySbLhDbg',
#  'KYyvaxVFqX4',
#  'yeGUTFvSf64',
#  'Q3GulJkMPCI',
#  '8hHNpJy6e-o',
#  'lPGIPqmCPEs',
#  'TRM_e1O7TVU',
#  'U_xZFqXOyFY',
#  'k7dmrSbCpy4',
#  'cffqyq-U2Og',
#  'xxwNglca0Bo',
#  'YZSv1Q8zuWo',
#  'njzjxMftEe8',
#  'hmxfn4cTdlQ',
#  'iXVGrwRxV2c',
#  'vW_LAxHJY_w',
#  'ZBVm07ywKoY',
#  'EMCNElHeamE',
#  '5OETMN8YU_A',
#  'tT46slhGCFA',
#  'DbuubsB0o3c',
#  'r1DvoBlySeA',
#  'sF1s5roiT6M',
#  'N-Xiil_Vzpc',
#  'jne7V_pvFOI',
#  'OLSwAYwBdxU',
#  'bA0bXoNgPD0',
#  '6exsUVxhT3E',
#  'iWdBB5ohJsg',
#  'naAVX3e3X7Y',
#  'yk8hwVc-sXQ',
#  'U9XV3jVXoN0',
#  'igL_mYeo8-s',
#  'O9zlJj87STI',
#  'XcRPHeKiHZo',
#  'Rd-Hddp4nZI',
#  'va5RVFB54M8',
#  'uCwTuKWA1dM',
#  'UWGxz964Ylc',
#  '-zKU5MDmVAI',
#  'PscKk1bwCBQ',
#  'R1VoEHceNMU',
#  'SFPBkwHx7w4',
#  'A1HFL165Mvg',
#  'KPTP4aebIRg',
#  'OaJDVHGAwHY',
#  'ty4pQr5d2BM',
#  'N0BJIswrJhw',
#  'ITc9gEkw08Y',
#  'KQIMFMrvD_0',
#  'FeCnik08spo',
#  'GiKAK1hD80E',
#  '_GsMKyb7Vx0',
#  'kfkqgkoq-jY',
#  'RHShzIl_2dE',
#  'CRypW3uQOyQ',
#  'Hk9fpWYibQY',
#  'f0cXJ6mJxGc',
#  'F6PqxbvOCUI',
#  'oA4LSZvX4iE',
#  'ZKxnjszkZto',
#  '8_gdcaX9Xqk',
#  'Pv0iVoSZzN8',
#  'CWbV3NItSdY',
#  'l-nMKJ5J3Uc',
#  'XE1Qyss8GIY',
#  '6GzHPS0rEgc',
#  'imhY0pe-Sd8',
#  'erLbbextvlY',
#  'OnTTThIzuNU',
#  'mKdjycj-7eE',
#  'tWYsfOSY9vY',
#  'sH48lKbayNU',
#  'AFXoSFNMwIA',
#  'AjwAdtlRKf8',
#  'KOEfDvr4DcQ',
#  'krsBRQbOPQ4',
#  '7ESeQBeikKs',
#  'K_CbgLpvH9E',
#  'lOKASgtr6kU',
#  '9RhWXPcKBI8',
#  'ZVt9ZJfWV1c',
#  'rWBOITBjitE',
#  'tnTPaLOaHz8',
#  'Wdjh81uH6FU',
#  '7dYTw-jAYkY',
#  'AjZDwxt7S8w',
#  'aZnqqXaT02g',
#  'mwKJfNYwvm8',
#  'l9_8_pDTmis',
#  'n7x4Jj9pdH8',
#  'QjvpjXdgugA',
#  'jGAJCAuV3pQ',
#  'c0v8OPItCOg',
#  '3ryID_SwU5E',
#  'IemzxkkzI5s',
#  '3OFj6l2tQ9s',
#  'bvlFjrcpD6s',
#  'AZlBZuS4hr0',
#  'Gx6VeIIbWwM',
#  'CAOY8EKH1qU',
#  'IQxea9UB1nQ',
#  'KrLj6nc516A',
#  'zgLhCT7aFCA',
#  'L5kIXRdwGAI',
#  '19NmWqv4Alk',
#  'vBpQ1SlfVtU',
#  'NnNZLCl78Ao',
#  'NTZhwAldqwg',
#  'J_z-W4UVHkw',
#  'mKIhHNznt4s',
#  'jObOjhUkf50',
#  'O3YVBJ2n5xg',
#  'yhB3BgJyGl8',
#  'CP82DAKzL1U',
#  'fuhE6PYnRMc',
#  'stUofW3whpE',
#  '48h57PspBec',
#  'ooAwCOP67GQ',
#  'FM7Z-Xq8Drc',
#  'WTOm65IZneg',
#  '8kggT2ej-lo',
#  'GGBy50KtvRk',
#  'Y4-gFIfGXiQ',
#  '1WEAJ-DFkHE',
#  'Y0cBiGUuB1Y',
#  'YLt73w6criQ',
#  'lglIQkCHO0g',
#  'TJ2ifmkGGus',
#  '7IKab3HcfFk',
#  'h5NvTTOlOtI',
#  'se50viFJ0AQ',
#  '0CTp1a-aCUM',
#  'FD-0KG-h2-c',
#  'kX3nB4PpJko',
#  'YlvcFJOE-OE',
#  'iogcY_4xGjo',
#  'S_CUEOBZ0P4',
#  'gHzuabZUd6c',
#  '65fN_OUawjk',
#  'jdMNoQE3mIQ',
#  '2isYuQZMbdU',
#  'tVWWp1PqDus',
#  'vaIgyRoUkQI',
#  'Hwybp38GnZw',
#  'hD1YtmKXNb4',
#  'LnlKwzc_TNA',
#  '3jS_yEK8qVI',
#  '00NgUctWoLQ',
#  'x9TQ6culXIA',
#  'QbJJwaVdgIs',
#  '0e3GPea1Tyg',
#  'cV2gBU6hKfY',
#  'qIsgdOVGA04',
#  'cExLQ1o2pDw',
#  'uocETPj4Jx4',
#  'zxYjTTXc-J8',
#  'hxwpkM5w3Cc',
#  'ktyJIj6i4Qw',
#  'urtFrxDUV6c',
#  'nM89Wl03Q4g',
#  'NZlClr_ivb4',
#  'E6E22XQPhhg',
#  'TQHEJj68Jew',
#  'WcwGleN38zE',
#  'fMfipiV_17o',
#  'ayXxwJJId_c',
#  '9bqk6ZUsKyA',
#  'DuQbOQwVaNE',
#  'vJH28ICkCdU',
#  '_uwNDiU04zE',
#  'C680oxL__ck',
#  '5Fg9oZk-5uA',
#  'PKtnafFtfEo',
#  'f0c7pSCoZqE',
#  'dg2Ag3e8W-Q',
#  'LeYsRMZFUq0',
#  'Dc2ZRmuH5OM',
#  'GLoeAJUcz38',
#  'SZQhgExjBvQ',
#  'IoZri9hq7z4',
#  'vp5sSqyZ5Go',
#  'AKJfakEsgy0',
#  'Vl3swga-Xrk',
#  'UE5AHE2Ypr8',
#  'TDiXxsQ0w2Q',
#  'oD155zWANQg',
#  's1ax8Tx_Jz0',
#  'NkE0AMGzpJY',
#  'FbM1yi4mMMc',
#  '5V2B28OqfqM',
#  'Rj_vssRaZlQ',
#  'YQDDm9HLkV4',
#  'erQ_9yEz0ls',
#  'OAbP-V6fEVc',
#  '_qAJMXfL6o0',
#  '59AYXzCa-Cs',
#  'r7zJ8srwwjk',
#  'YSoJPA8-oHc',
#  '5Hg_QSIJm8I',
#  'gsWPpE4Rid0',
#  'HBMmK1c44sE',
#  'oBYbxw8f5OI',
#  'AiGKBNGlzHo',
#  '_mdKvblL_8s',
#  'yXWw0_UfSFg',
#  'F4Y3Pkn95GI',
#  'KSKJKLmAqpI',
#  'IYVjOfoU3uI',
#  'oI6aXhowFDY',
#  'LdMx2U5tby0',
#  'fY-LA3YaZ_M',
#  '0hVZOJCYBBM',
#  'Z9WQy9jEY8M',
#  'bs0SWXbty18',
#  'yeqARWqjkps',
#  'wMuYiLby3-s',
#  'NbaWrbJDr48',
#  'sfv1QaRzJg8',
#  'RwnN2FVaHmw',
#  'X1jMMFOqxEw',
#  'ORUX1lHbOa8',
#  'LU_xVr4b2qM',
#  'tQ4m4zD7BBA',
#  'D9lVNzyhYnc',
#  'jokVbbLqV_E',
#  'HPJKxAhLw5I',
#  'Ims5p6wjW9s',
#  'anFxsa5jXrE',
#  'QxGVgXf_LNk',
#  'al6130OD1Ck',
#  'd1010B3sKNQ',
#  'NS3hse9ezik',
#  'npDey6_9YRs',
#  '0NGWT9COcEI',
#  '3LLnjRLrvLU',
#  'bTrV5v7GLcQ',
#  'lBYC4_Lccjw',
#  'gL6iSCSHjco',
#  'UQtltNZ_pjs',
#  '0DaMUhgcAqo',
#  'TOcGSwJBPMQ',
#  'ws694xrKopA',
#  'UtnsWzaoRtg',
#  '6wsFjjhZPJI',
#  'Rmf6T_Ewt38',
#  'n6qc4LHN2KQ',
#  '2eFSU7TFOnk',
#  'RCvnytndd9c',
#  'AA-VpIj8F5Y',
#  'fWcSBWadolA',
#  'YyhKdOCwD7s',
#  'ha4tRQwKIUg',
#  'xRwy_rKc7gI',
#  'H1WBdh56Vq4',
#  'xhIYirjB4Yc',
#  'HfJMs4mrSJM',
#  'tYHTVjfShOA',
#  'JTQcIR2ZxU4',
#  'xpNeg0hPZIs',
#  '9yrdFAJUSaU',
#  'i2O6GMpNWGo',
#  'Y6jC6VaO3j0',
#  'Ooke4YZv8Ts',
#  'ZV7rU6lnAKQ',
#  'iUzi5JmJNWc',
#  '9cCpZl8euLI',
#  'I046_n20d3s',
#  '2nd73lyvq4w',
#  'nuM0Z4a7kMs',
#  'qPBtTPJHS0Q',
#  'A-vX1AGBGsc',
#  'IiW2smvEcBM',
#  'q6Qw8mUVTrE',
#  'dBxOYE2j55U',
#  '984NGLLYDUg',
#  '7zi0bi-RDj4',
#  'XaxhLbxZ13k',
#  'L8nh1wuXTbI',
#  '9-HphHIJS9c',
#  'rPXmbM2UEbU',
#  'sESRuTyfsEk',
#  'QapO3maXd9k',
#  '71VpdDb8e6U',
#  'Su34c5Z8DW4',
#  'e5DqdX-7_g4',
#  '9vB-48kHbBU',
#  '3ix_gbcubTo',
#  'mGIpOtncmSM',
#  'VqnQ-0q2gb4',
#  '3TflpIllQHY',
#  '1SwVSTKFCsc',
#  'ZPuEUe_8SRM',
#  'gKVZz4kcuns',
#  'nywT2SenPIo',
#  'xBP9EUQIkNs',
#  'qZNxvnQv0h4',
#  'uE6gud1voDs',
#  'f0M64XpmTz8',
#  'Gz3yak1cl-8',
#  '9GD6hbqu2oM',
#  'GUWGsIVEMSQ',
#  'wDqJZ_2ZA3A',
#  'RywkkwO78m8',
#  'P4qWhSZ7_WA',
#  'UlUcwJc5nBs',
#  'qAW6CE7_bFM',
#  'tBEBc4KQVsU',
#  'q0OK-zHnvnA',
#  'bFZdU9dr4OM',
#  'nd-bwvNB7YA',
#  '6_im_hGxGRk',
#  'b91vrgVY-ZQ',
#  '52ubXjlVzUY',
#  'XHb7g6yuGgE',
#  'rH1D_3G56DY',
#  '-0zoWMSEOGg',
#  'WRzIuC2MKOU',
#  'foLlul8Tl3E',
#  '3iaDrpKdaIc',
#  'qrIh-ZHN4-E',
#  'mpZWt5pGKZ8',
#  'vbph9F_pRNI',
#  'XE9pUM9MEFA',
#  'wbzD04leeLI',
#  'MC5h-ShR-S8',
#  'dp8IaLrZpGs',
#  '97Gh93Daio0',
#  't4OumncEiKo',
#  'Ejou8aa5eZk',
#  'ehEuczQUh8E',
#  'uBC7805Smsg',
#  'd8pJkuSp1iI',
#  'dFr5YQaQQdo',
#  'xBLxMfO3pDw',
#  'd7QmQtNwhcU',
#  'NZR4WEjpOQg',
#  'vETSAZgfDP4',
#  'zE3FLbpu9-Q',
#  'Izmibu7dxcs',
#  '2Pvt8awds44',
#  'n9BbAfbsyj0',
#  'WZ2rYlVxt4g',
#  'CWK6an4mYL0',
#  'VwWV4JelEzY',
#  'koRKIlRQj4g',
#  'XKFKPQHdWRI',
#  'yuGEB4ZZdUQ',
#  'sg_XFT4K3N4',
#  'szt8xabJoSo',
#  'Fbl3E_XCQfA',
#  'Pe3pGsCeYXg',
#  'yzGmnjDFuZE',
#  'op0N7axawJA',
#  'l_huIWJBhJM',
#  '7ALCsEyn3mg',
#  'CvMRiR4k49Y',
#  'g2rbhIB-ITM',
#  'nLpqZEAFnkE',
#  'sirrTXiPFmw',
#  'nRkwuTOESCc',
#  'AS6WMS_Bemg',
#  'wMn8d7IeCYM',
#  'BMZP4CtphaU',
#  'ln9aLVd__8w',
#  '93s1JECSy60',
#  'YR6Wh2Zy9jE',
#  '5PCxQSMOl3o',
#  '5qzAVMe_SnM',
#  'zAAXW7ySu1k',
#  'sx5k8xd_VoU',
#  'uotb9ZHnI2g',
#  'nPlqRbVFBHI',
#  '_FX6rml2Yjs',
#  'kupaqq-xJ_8',
#  'Er6QUQZbv0w',
#  '4KVmSG6KS2k',
#  'Lx9fRu5ehFo',
#  'KcsRxHwGz7A',
#  'ZJwX2jTXWwQ',
#  'N_GMakKf7G4',
#  '63gyUQ_JeOE',
#  'IZVbzNRUlQI',
#  '8D3vI1615K4',
#  'igVcy5dtN80',
#  'dEOlvTqYUNo',
#  'AS5CxLCWq-Q',
#  'jtOalDNVrKM',
#  'dDYP56hEYF0',
#  'pJSbLk-Iixc',
#  'iengNekeTNo',
#  'rqUvnLPvbrM',
#  '9CVwXBYVqVk',
#  'i8pmk5xnO2s',
#  'xWcldHxHFpo',
#  'YH1-fDzHHpo',
#  'ntlG5XgYg4k',
#  'Qy17S3g8ZuY',
#  'PJyWmlWNor8',
#  'KzwTYZ2W3ZA',
#  '9fa_JYTPZ2Y',
#  't1BWMa8btIw',
#  '2O8wta4FsD4',
#  'dSDBr0WjrwQ',
#  'DbC9CauTXoM',
#  'yhNcDBnQsEY',
#  'Wyyqz3OxB5c',
#  'KO8B2kw_Jxs',
#  'NEDPgQYhbqs',
#  'DpIvW6av0pI',
#  'RPcXg2-0ejw',
#  'jhYG5BStQSk',
#  'wTIPpjUgAFE',
#  'Fzh65vCyHWQ',
#  'vBp0bzVr09s',
#  'AXjdI_LHWJU',
#  'dJCsc_Cq9i4',
#  'bqpKlkPpT10',
#  'TIIU1ivhLKs',
#  'G4qOiwIE_o0',
#  'yozl6enFC-w',
#  'LP_mGU3CgXk',
#  'DoIQMkoYSzw',
#  'e-If_d_bzfI',
#  '5J6-5g2alp8',
#  'qjGNBluF6_I',
#  'TLoDwqQF5ug',
#  'uAFGIQPWL54',
#  'SaDDjW9Rw-M',
#  'CHdy9wND1jo',
#  '9LiS_3HEErU',
#  'hRj5qNfkdO0',
#  'ocruJKe2tFk',
#  'MgRMNzKknto',
#  'tqO3_AKC5Ks',
#  'XW1TsAVdXsw',
#  'Qhdj_Umh1IE',
#  'fN_RQFqaGHI',
#  'hC3xW8xeCDs',
#  'xGJEPTCw9GU',
#  'FmjsePPBbdU',
#  'lMLEcUXz6T8',
#  'BKJy7BFP3Is',
#  '1gfgZhW3YgU',
#  'VXmKt_1T0QM',
#  '6XCUHLhdnEY',
#  'ttWTSskmxTA',
#  '5bCyFf8lSfk',
#  'ngVEpJs5A5s',
#  'zjC48c3ptt0',
#  'rS2sntC-lJI',
#  'fG1N5kzeAhM',
#  'vT_gRRMjDi0',
#  'dfcPUqiivDY',
#  'zCR6DJX7Kak',
#  '4cX-w-ia0RU',
#  '2nVjy-zd65Q',
#  'xlzpD4GeBW0',
#  '8ZTy3K2QgOY',
#  'k9zko79_3_I',
#  'fYnPyLfxSJg',
#  'pBH_QL4JGcI',
#  '1wtFD9zSQO8',
#  'VqhjiwmGNKA',
#  'EhZ9gHZOZT8',
#  'LHtkve6-O0g',
#  'm3Ol8zn7brk',
#  'qBiZA4QDsj0',
#  'NeOrh4GnPZ4',
#  'fWhfOAuOqjY',
#  '9Ax56oRhcZc',
#  '-cWVrFABWHw',
#  'z7qtJAAV5d0',
#  '9pk-neTrDoM',
#  'JQscW6DfNZY',
#  '9smE_EiKJ8Q',
#  'hfaPkoXeYfU',
#  'u0hHxeWkB_o',
#  '64WGWubQO3I',
#  'QJUs6CSRCFU',
#  'Om4c4ilT_6g',
#  'GbOfxRfHdeg',
#  'yzxYCRDcGDs',
#  'PCakYf_PnT0',
#  '8nv_ltg4RAg',
#  'VvphlSvCyj8',
#  'JP3v6UxI124',
#  'jRURlbRAUhI',
#  'I_3R9YGFlHE',
#  'xjJJ_wDlc1E',
#  'cqirhwhq_qM',
#  '3IQdDBwc42o',
#  '4YHnf3YepwU',
#  'uxzBq4Y_fNw',
#  'HIhUkvAG0o4',
#  'cpI5lCaqZcQ',
#  '6zQhLOw1nw8',
#  'mfvi_jgdVqE',
#  'zExxMxcoJ6A',
#  'hD_Af6W2qug',
#  'XOtTKQujlkI',
#  'dRqthQ2Mc_0',
#  '8TFq_vvO_Wg',
#  'oo8ve4Ldpck',
#  'sKn8Tbp2a-4',
#  'g0IrVKXIbmE',
#  '2Om2M4_Kyd0',
#  'KaaEivIqX6M',
#  'W4gBpws7Ug8',
#  'NT3EkjxO8hs',
#  'syMozMiJneM',
#  'Wt6cMjn3YLg',
#  'OEuS7fjMlMc',
#  '1Pr-R2nKTY4',
#  'QqdUhn99E-s',
#  '1UygJmcHUdQ',
#  'g4DAFnZcCcQ',
#  'LTr8cXAxy1I',
#  'Ow3xqv7ahXo',
#  'TRiF8PdrIP8',
#  'NFZ_MtTvwm0',
#  'Pgxi8dsUW-o',
#  'YY2-jJojnOA',
#  '7Pogam71094',
#  'DL0OPJ2hahc',
#  'WwE0tR08OTU',
#  '2LIJtcI4dbg',
#  'rXnaD7PU9kY',
#  'Ng_qwlvhrJo',
#  'bzIPun3cVsw',
#  'miKQkeq5sbU',
#  'Lwt_VThQIdM',
#  'P2oPACr4uuU',
#  'h-D6ukDcS9o',
#  'mY77HA20MzA',
#  '4krBgDFycgY',
#  'dpUxRIqbNlc',
#  'Cp431S5z8PE',
#  'ttLYXcza4j4',
#  '3-f9DEFsh4w',
#  'vuOTP206zWM',
#  'J590MYm0SY8',
#  'vGB2d5cQJpY',
#  'M94G0iKYiSM',
#  'pGYyUssWLTA',
#  'j7kM8G_AjuY',
#  'deK-My3Of0o',
#  'oB8kFFvJdhE',
#  'X9eXa-Uzuj0',
#  'GxTVDClFXuc',
#  'kGaq-Qi9hoE',
#  '9zFfp3gzZ88',
#  'mM2KwBYa-u4',
#  'WAcmsAISniQ',
#  'kqUT-s3a6tU',
#  'NUVglXbGBfs',
#  'T-v4b3WtPAg',
#  'm8qGlpcfAIw',
#  'afL8tYlnrj4',
#  'uZPkMnv8b-o',
#  'qVLr6SMxvJw',
#  '4AigP5OY8JE',
#  'RMoFUeBVefA',
#  'ep7S1XnuQLU',
#  'p6bzNpgbX8Y',
#  '6T17licWsQ4',
#  '1s6UOlWdpw4',
#  '3LuchpUc7PU',
#  '_f6xCA0-gAo',
#  'lfD7kMZKuNg',
#  'ejlkNGm82w4',
#  'Jtj9rUqlB1Y',
#  'ZqzFRGH_tMQ',
#  '94A-bsumX9A',
#  'gYaxI_allkQ',
#  'AjXbO2XfBkE',
#  'ZQZzR0DUujc',
#  '-V3-fhJQZkk',
#  'QX0wvWGW2qg',
#  'oODUkNQAzXU',
#  '2jWZtKTN6jU',
#  'zsADECFHY8w',
#  'Feh8o-HmthM',
#  '6Xv-LVYZQxk',
#  '8-0ZHJHp9g4',
#  'QqIG0R-KpGk',
#  'qENpZBzgaUM',
#  '4DYBVA4884Y',
#  'skEf9R0TXkM',
#  'CnMv_zTXZ38',
#  'bEIK5ni_Pzs',
#  '_oZyp4mTzSQ',
#  'is1LSWbssuA',
#  'XR_q9_LEKuc',
#  'X9UiBpDHW3w',
#  'PRU47AuQF2M',
#  'Y3Rxgf5_R_I',
#  'R6zuvKbvKyU',
#  'yCKe65Nvp0Q',
#  'XBe57FyB2xU',
#  'zpCwHwWgbsI',
#  'lh61MVUxJt0',
#  'yWnmEPgLroQ',
#  'eBklqeeIu10',
#  'SgMydsOucFg',
#  'jPm3hRiMKuU',
#  'OweuuinkVZI',
#  '7Pr0HP-Trgk',
#  'UEK0fYAqMss',
#  'lRznKN2oPUc',
#  'IDrS_TrjuK4',
#  'J1lhxfZtR3M',
#  'b_o8cz0ZNdk',
#  'i5dhcAxO25Q',
#  '-o_8CDbFMJ0',
#  'v5J1Cycn3s8',
#  'YJiqYG-Mylk',
#  'jGE1sUTeR5g',
#  '0tZCQ25fsoI',
#  'N9jTogPwqVY',
#  'yyJ7xEcENNI',
#  '3rJgCGMPEqA',
#  '7isfkomGg7o',
#  'UCYefSGBP00',
#  'dvdGkRK5a_0',
#  'X7doE4h6W64',
#  'GhppzOzN3MM',
#  'QkXDatNdL4U',
#  'hyt2t4r8lQ4',
#  '-mlok5iT3GE',
#  'STvOHHgJ1sQ',
#  '2-ErX5oDzwM',
#  '7ytYV-tVIvg',
#  'ELIoOUKSOJQ',
#  'uAoayezOaug',
#  'Vr2337tCLCI',
#  'NV7qmqbS8tM',
#  'U9c-ycvw02A',
#  'GfgcVOuHLAo',
#  'zi7tZ-2PhLk',
#  'TacjQmKCiZg',
#  'AIytwdufwW8',
#  'KLAI0c0Spog',
#  'UVin8WtE5eU',
#  'wNuxirsrwBk',
#  '6bxZpS0cm5o',
#  'ajJbMGq9AS4',
#  'UXw9jqgJNNc',
#  'E3CqKvlzl-I',
#  'zfDr05ax0gM',
#  '56OkH6ocYZU',
#  'w40Z8aT5fpQ',
#  'zgDezsMQyyU',
#  'UEwnitHoSDw',
#  '__SaaKSW9iE',
#  'qWnyJ55KBKo',
#  '52awie9G00A',
#  'bB99NdUoxEQ',
#  '7GjSaNi8Epg',
#  'h5uE4ERMiTk',
#  'umRLkCrmwcs',
#  'rHoLyltYDtQ',
#  'yeHjsYQ076A',
#  'pqrdPu2ESFo',
#  'ywZy_Fo2ydo',
#  'qr4v9pdfVlU',
#  'hgiPX33AHas',
#  'oZ-Mn5p1xMw',
#  '5UPa_hu5opg',
#  'zv_oq5UNDAo',
#  'NiqkH7qVW0U',
#  'boBokLXe5o8',
#  '7YOzgk-U4EU',
#  'prdSftLj9-g',
#  'pzlPJmNyepA',
#  'QNoqAnJOSqU',
#  'kzIA4vKyhRQ',
#  'DfonKqMENrg',
#  'MUQCwdkEbq0',
#  'JlUzoQN9FWw',
#  '0VjLq-go1fg',
#  ...]

# %%
def get_video_details(youtube, video_ids):    
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
videoDetails=get_video_details(youtube, Video_ids)
videoDetails
# Out:
#          video_id       channelTitle  \
# 0     Fj-g-cmSzbo  Rohit & Kanupriya
# 1     JXvx90MmuG8  Rohit & Kanupriya
# 2     9ay_GsacYWs  Rohit & Kanupriya
# 3     -hPbCw8XzkQ  Rohit & Kanupriya
# 4     yXoqz_GOJxw  Rohit & Kanupriya
# ...           ...                ...
# 2772  tOxfKa8FjEY     Darshil Parmar
# 2773  yQvuiqUNPVY     Darshil Parmar
# 2774  eT4V2cYrZrM     Darshil Parmar
# 2775  XCc01fcb7EI     Darshil Parmar
# 2776  1jJp8TevYvs     Darshil Parmar
#
#                                                   title  \
# 0     Beautiful but toxic. #Funny #comedy #couple #e...
# 1           Editing our shorts and reels AND an UPGRADE
# 2     Good boy VS Bad boy #funny #comedy #couple #ex...
# 3                 Happy Mother’s Day. #mothersday  #mom
# 4     When you see a hot guy. #Funny #comedy #couple...
# ...                                                 ...
# 2772  Beginner Level Skills for Data Engineering (2022)
# 2773  Data Engineer vs Data Scientist vs Machine Lea...
# 2774  Data science is the best career for you in 202...
# 2775  My strategies to crack AWS Certified Solutions...
# 2776  Data Engineering SIMPLIFIED! | Skills required...
#
#                                             description  \
# 0
# 1     Was feeling extremely low because of the heats...
# 2
# 3
# 4
# ...                                                 ...
# 2772  What skills are a must-have when you are just ...
# 2773  Data Engineer vs Data Scientist vs Machine Lea...
# 2774  Is Data Science a promising career in 2022? \n...
# 2775  AWS Certified Solutions Architect - Associate ...
# 2776  Who is a Data Engineer? and What do Data Engin...
#
#                                                    tags           publishedAt  \
# 0                                                  None  2024-05-14T15:06:55Z
# 1     [editing, rohit and kanu, rohit and kanupriya,...  2024-05-13T15:14:10Z
# 2                                                  None  2024-05-13T14:54:22Z
# 3                                                  None  2024-05-12T05:43:39Z
# 4                                                  None  2024-05-11T14:41:34Z
# ...                                                 ...                   ...
# 2772  [Skills for data engineer, Skills required to ...  2021-06-17T07:01:58Z
# 2773  [data engineer, data scientist, data scientist...  2021-06-09T03:30:08Z
# 2774  [What is data science, how to learn data scien...  2021-06-02T03:30:04Z
# 2775  [AWS Certification, AWS 2022, Cloud certificat...  2021-05-16T11:38:36Z
# 2776  [Data engineer, Big Data, Data Science, Data e...  2021-05-10T07:11:05Z
#
#      viewCount likeCount favouriteCount commentCount  duration definition  \
# 0       801431     56093           None          257      PT1M         hd
# 1        18016       468           None           85  PT31M57S         hd
# 2      1626649     96485           None          585     PT59S         hd
# 3       652233     41210           None          229     PT27S         hd
# 4      3328620    164257           None          559     PT44S         hd
# ...        ...       ...            ...          ...       ...        ...
# 2772     53891      2006           None          106   PT6M38S         hd
# 2773      4089       172           None           35    PT5M1S         hd
# 2774      2162        92           None           26   PT5M54S         hd
# 2775     64646      2071           None          154   PT6M25S         hd
# 2776     10117       437           None           56   PT5M55S         hd
#
#      caption
# 0      false
# 1      false
# 2      false
# 3      false
# 4      false
# ...      ...
# 2772    true
# 2773   false
# 2774   false
# 2775   false
# 2776   false
#
# [2777 rows x 13 columns]

# %%
videoDetails.to_csv('Data\\apiData.csv', index=False)
