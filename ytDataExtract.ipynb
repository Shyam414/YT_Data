# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# %%
api_key = input("Please enter your YouTube Data API key: ")
channel_ids=['UCX6OQ3DkcsbYNE6H8uQQuVA',
             'UCChmJrVa8kDg05JfCmxpLRw',
             'UCkX0NXCP9kCLtk30kjTXIWg',
             'UCXqJrBG563pZnaqLoxHjUDg',
             'UCHoLIMtg_OigNlJmjHX9J8Q',
             'UCMOLiZpKXp-w5CNfqJObQUw',
             'UCtAXJ4DNpshfVjLIMq9pIRw']

youtube= build('youtube','v3',developerKey=api_key)

# %%
def get_channel(youtube,channel_ids):
    
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids)
                )
    response = request.execute() 
    

    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
channel_stats=get_channel(youtube,channel_ids)
channel_stats
# Out:
#          channelName subscribers        views totalVideos  \
# 0     Darshil Parmar      129000      5981018         150
# 1            MrBeast   257000000  48645679881         793
# 2            coder2j        9980       925471          48
# 3   Something_beyond          18         8547          46
# 4          KEEMOKAZI     9760000  10650191154        1337
# 5              KALEO     1950000   1553977588          68
# 6  Rohit & Kanupriya     2290000   2181237212         329
#
#                  playlistId
# 0  UUChmJrVa8kDg05JfCmxpLRw
# 1  UUX6OQ3DkcsbYNE6H8uQQuVA
# 2  UUHoLIMtg_OigNlJmjHX9J8Q
# 3  UUkX0NXCP9kCLtk30kjTXIWg
# 4  UUMOLiZpKXp-w5CNfqJObQUw
# 5  UUXqJrBG563pZnaqLoxHjUDg
# 6  UUtAXJ4DNpshfVjLIMq9pIRw

# %%
playlistid=channel_stats['playlistId']
playlistid
# Out:
# 0    UUChmJrVa8kDg05JfCmxpLRw
# 1    UUX6OQ3DkcsbYNE6H8uQQuVA
# 2    UUHoLIMtg_OigNlJmjHX9J8Q
# 3    UUkX0NXCP9kCLtk30kjTXIWg
# 4    UUMOLiZpKXp-w5CNfqJObQUw
# 5    UUXqJrBG563pZnaqLoxHjUDg
# 6    UUtAXJ4DNpshfVjLIMq9pIRw
# Name: playlistId, dtype: object

# %%
def get_video_ids(youtube, playlist_id,video_ids):

    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
video_ids = []
for i in range(len(playlistid)):
    playlist_id=playlistid[i]
    Video_ids=get_video_ids(youtube, playlist_id,video_ids)
    
Video_ids
# Out:
# ['r_K9hznoPKU',
#  '0iNJPKheQqM',
#  'XnPF-MDMUzc',
#  'V7ue-tM2aYU',
#  'KV4hZR5-D-4',
#  'Ihm53yWftI8',
#  'AUb1il2F73c',
#  'VIJH7TZXkaA',
#  'X8Fin2zMKK4',
#  'mFImgE4jpB8',
#  'HxdoBLc5_Qc',
#  '2OikDCZSPbM',
#  'JFCiH6ZALls',
#  '1CI3dSP6jCY',
#  'IQNVoPi1ww0',
#  'C3upc-3JAYY',
#  'CP93kY8KFxM',
#  '5peQThvQmQk',
#  'CUbN0m4-ZdM',
#  'cRYhNExua-E',
#  'H3lqFz0MryQ',
#  'G5kl769LIzI',
#  '5Nh9aCpvo6w',
#  'IaA9YNlg5hM',
#  'NiS4Ijl9qFQ',
#  'v_uodKAywXA',
#  '_qHY1u-Ht40',
#  'MN9ldvzTysM',
#  'Gh7v6XCHNxU',
#  'o3OZIQxGvyI',
#  'JDRfdFBxDJ8',
#  'WpQECq5Hx9g',
#  'gAk9m_d27yk',
#  'leElg0VdfG4',
#  'eZSADEjm-TM',
#  'saM0zSdd158',
#  'B4UieGv9HJk',
#  '5mpUFFtSxKk',
#  '4VYiS81LyDs',
#  'ZC6KKOCX4kg',
#  'alrP72UoDWw',
#  'ndELocWl3iA',
#  'KerNf0NANMo',
#  'sqiURk9YFLc',
#  '2hPCX-p_X8Q',
#  '5CA8LenDMig',
#  'nr9ujxeCOfA',
#  'q8q3OFFfY6c',
#  'gFV-bt7THmA',
#  'yuMwQy4ZhTA',
#  'fzyv5wxAeG8',
#  'NRNkSXo6QbU',
#  'Ho-s7_bj9lE',
#  'hM6BM4u9aVg',
#  'fhbNVb_LXDw',
#  'UIZdjAKadc8',
#  'FFdSqolMyoI',
#  'GK4ZspWv0pg',
#  'WKJKKI6eoTE',
#  'rOJZE_psWvU',
#  'Xhno8EnMyU8',
#  'I1aIlIzRRxk',
#  'hdMDCHoc7G0',
#  'IWQV5I5d_cE',
#  'bH7V3q2uX1U',
#  'UqZtjp2Ti7s',
#  '2hzfWjbeMGo',
#  'Fikmb0B-sHs',
#  'kU58_NaEjCk',
#  'LxyudhEl8pE',
#  'IkJteY0qX3I',
#  'SxhjGwBJhxc',
#  'u_TbaIDFoOg',
#  'fCEHe90EArM',
#  'MTrbVUCjWP8',
#  'mp_ewK7oSLc',
#  'bIcLOItLQlY',
#  'Mk93KsqA9Gs',
#  'sGPWVYriqW4',
#  'o-pzebYQ7z4',
#  'yZKJFKu49Dk',
#  'TF1xhgt2AaY',
#  'nxiVCrR4rRM',
#  'WRCmVDG-H2Y',
#  'iqmt_wX_ay4',
#  'wM9gL2E5rkw',
#  'F9R-m4Wu1Qg',
#  'RRjL84YamOA',
#  'G2iviiIcVgA',
#  'Y6Yv01aPHz8',
#  'aeQy9XXOEHA',
#  '14Cwd3urG0E',
#  'FS-0t6kVPvo',
#  'i5x-TIilCcA',
#  'SmdWcfomD_Y',
#  'NK2D5pwJuso',
#  'cwvYQEptP9A',
#  'c4E4xQCA0cU',
#  'qBocgdMGEWs',
#  's1_XgRod0Fk',
#  'tW6g_WbwAl0',
#  'AS2EyYK4x_Q',
#  'gFWu-SSzRzc',
#  'OZidfeo0rts',
#  '4P37f9OfH_A',
#  'fHA_JYECg0c',
#  'BopMJPEH6AE',
#  'ZZ5K0A-9bqs',
#  '3v2NaBczURY',
#  'Tw-I8E1Njto',
#  'yMvMs_vDNAU',
#  'P27WNlrGwNs',
#  'tqXo-7lNguk',
#  'm1rudjGBY8c',
#  'w0XWtFaRNYQ',
#  'BJKCQ9ld-Ac',
#  'kbPlzXBAqzI',
#  'zEqpdnuIrh4',
#  'p_QAKiUBERw',
#  'KUiHuWAl6rU',
#  'kbtDJHgjrPc',
#  'lQ9AtozWGrg',
#  'QHIOX_RqjLI',
#  '52wUGD6XB8c',
#  'vob1PBhyng8',
#  'i73ZNZvT21I',
#  'ViwHbjVtG20',
#  'khZhLzyvOg4',
#  'yUHzlOP6EZ4',
#  'BCpuPl9POr8',
#  'VFoYw6sDCEg',
#  'HU8K6o8nrJA',
#  'POjDCe-_G8k',
#  'NToi35FSSnA',
#  'K45k-gNNzGo',
#  'VIHvGc4Wo60',
#  '2xyoz0T47Bs',
#  'qkmlJ2puHdc',
#  'eInHnOxTA-0',
#  'w9yfVLcEuM0',
#  'TcKkfZHbHS8',
#  'NsK6zrp61mY',
#  'p_Oqp4C6O38',
#  'MSLzG5sY5_8',
#  'eNMZq3FBq_8',
#  'tOxfKa8FjEY',
#  'yQvuiqUNPVY',
#  'eT4V2cYrZrM',
#  'XCc01fcb7EI',
#  '1jJp8TevYvs',
#  'F6PqxbvOCUI',
#  'oA4LSZvX4iE',
#  'ZKxnjszkZto',
#  '8_gdcaX9Xqk',
#  'Pv0iVoSZzN8',
#  'CWbV3NItSdY',
#  'l-nMKJ5J3Uc',
#  'XE1Qyss8GIY',
#  '6GzHPS0rEgc',
#  'imhY0pe-Sd8',
#  'erLbbextvlY',
#  'OnTTThIzuNU',
#  'mKdjycj-7eE',
#  'tWYsfOSY9vY',
#  'sH48lKbayNU',
#  'AFXoSFNMwIA',
#  'AjwAdtlRKf8',
#  'KOEfDvr4DcQ',
#  'krsBRQbOPQ4',
#  '7ESeQBeikKs',
#  'K_CbgLpvH9E',
#  'lOKASgtr6kU',
#  '9RhWXPcKBI8',
#  'ZVt9ZJfWV1c',
#  'rWBOITBjitE',
#  'tnTPaLOaHz8',
#  'Wdjh81uH6FU',
#  '7dYTw-jAYkY',
#  'AjZDwxt7S8w',
#  'aZnqqXaT02g',
#  'mwKJfNYwvm8',
#  'l9_8_pDTmis',
#  'n7x4Jj9pdH8',
#  'QjvpjXdgugA',
#  'jGAJCAuV3pQ',
#  'c0v8OPItCOg',
#  '3ryID_SwU5E',
#  'IemzxkkzI5s',
#  '3OFj6l2tQ9s',
#  'bvlFjrcpD6s',
#  'AZlBZuS4hr0',
#  'Gx6VeIIbWwM',
#  'CAOY8EKH1qU',
#  'IQxea9UB1nQ',
#  'KrLj6nc516A',
#  'zgLhCT7aFCA',
#  'L5kIXRdwGAI',
#  '19NmWqv4Alk',
#  'vBpQ1SlfVtU',
#  'NnNZLCl78Ao',
#  'NTZhwAldqwg',
#  'J_z-W4UVHkw',
#  'mKIhHNznt4s',
#  'jObOjhUkf50',
#  'O3YVBJ2n5xg',
#  'yhB3BgJyGl8',
#  'CP82DAKzL1U',
#  'fuhE6PYnRMc',
#  'stUofW3whpE',
#  '48h57PspBec',
#  'ooAwCOP67GQ',
#  'FM7Z-Xq8Drc',
#  'WTOm65IZneg',
#  '8kggT2ej-lo',
#  'GGBy50KtvRk',
#  'Y4-gFIfGXiQ',
#  '1WEAJ-DFkHE',
#  'Y0cBiGUuB1Y',
#  'YLt73w6criQ',
#  'lglIQkCHO0g',
#  'TJ2ifmkGGus',
#  '7IKab3HcfFk',
#  'h5NvTTOlOtI',
#  'se50viFJ0AQ',
#  '0CTp1a-aCUM',
#  'FD-0KG-h2-c',
#  'kX3nB4PpJko',
#  'YlvcFJOE-OE',
#  'iogcY_4xGjo',
#  'S_CUEOBZ0P4',
#  'gHzuabZUd6c',
#  '65fN_OUawjk',
#  'jdMNoQE3mIQ',
#  '2isYuQZMbdU',
#  'tVWWp1PqDus',
#  'vaIgyRoUkQI',
#  'Hwybp38GnZw',
#  'hD1YtmKXNb4',
#  'LnlKwzc_TNA',
#  '3jS_yEK8qVI',
#  '00NgUctWoLQ',
#  'x9TQ6culXIA',
#  'QbJJwaVdgIs',
#  '0e3GPea1Tyg',
#  'cV2gBU6hKfY',
#  'qIsgdOVGA04',
#  'cExLQ1o2pDw',
#  'uocETPj4Jx4',
#  'zxYjTTXc-J8',
#  'hxwpkM5w3Cc',
#  'ktyJIj6i4Qw',
#  'urtFrxDUV6c',
#  'nM89Wl03Q4g',
#  'NZlClr_ivb4',
#  'E6E22XQPhhg',
#  'TQHEJj68Jew',
#  'WcwGleN38zE',
#  'fMfipiV_17o',
#  'ayXxwJJId_c',
#  '9bqk6ZUsKyA',
#  'DuQbOQwVaNE',
#  'vJH28ICkCdU',
#  '_uwNDiU04zE',
#  'C680oxL__ck',
#  '5Fg9oZk-5uA',
#  'PKtnafFtfEo',
#  'f0c7pSCoZqE',
#  'dg2Ag3e8W-Q',
#  'LeYsRMZFUq0',
#  'Dc2ZRmuH5OM',
#  'GLoeAJUcz38',
#  'SZQhgExjBvQ',
#  'IoZri9hq7z4',
#  'vp5sSqyZ5Go',
#  'AKJfakEsgy0',
#  'Vl3swga-Xrk',
#  'UE5AHE2Ypr8',
#  'TDiXxsQ0w2Q',
#  'oD155zWANQg',
#  's1ax8Tx_Jz0',
#  'NkE0AMGzpJY',
#  'FbM1yi4mMMc',
#  '5V2B28OqfqM',
#  'Rj_vssRaZlQ',
#  'YQDDm9HLkV4',
#  'erQ_9yEz0ls',
#  'OAbP-V6fEVc',
#  '_qAJMXfL6o0',
#  '59AYXzCa-Cs',
#  'r7zJ8srwwjk',
#  'YSoJPA8-oHc',
#  '5Hg_QSIJm8I',
#  'gsWPpE4Rid0',
#  'HBMmK1c44sE',
#  'oBYbxw8f5OI',
#  'AiGKBNGlzHo',
#  '_mdKvblL_8s',
#  'yXWw0_UfSFg',
#  'F4Y3Pkn95GI',
#  'KSKJKLmAqpI',
#  'IYVjOfoU3uI',
#  'oI6aXhowFDY',
#  'LdMx2U5tby0',
#  'fY-LA3YaZ_M',
#  '0hVZOJCYBBM',
#  'Z9WQy9jEY8M',
#  'bs0SWXbty18',
#  'yeqARWqjkps',
#  'wMuYiLby3-s',
#  'NbaWrbJDr48',
#  'sfv1QaRzJg8',
#  'RwnN2FVaHmw',
#  'X1jMMFOqxEw',
#  'ORUX1lHbOa8',
#  'LU_xVr4b2qM',
#  'tQ4m4zD7BBA',
#  'D9lVNzyhYnc',
#  'jokVbbLqV_E',
#  'HPJKxAhLw5I',
#  'Ims5p6wjW9s',
#  'anFxsa5jXrE',
#  'QxGVgXf_LNk',
#  'al6130OD1Ck',
#  'd1010B3sKNQ',
#  'NS3hse9ezik',
#  'npDey6_9YRs',
#  '0NGWT9COcEI',
#  '3LLnjRLrvLU',
#  'bTrV5v7GLcQ',
#  'lBYC4_Lccjw',
#  'gL6iSCSHjco',
#  'UQtltNZ_pjs',
#  '0DaMUhgcAqo',
#  'TOcGSwJBPMQ',
#  'ws694xrKopA',
#  'UtnsWzaoRtg',
#  '6wsFjjhZPJI',
#  'Rmf6T_Ewt38',
#  'n6qc4LHN2KQ',
#  '2eFSU7TFOnk',
#  'RCvnytndd9c',
#  'AA-VpIj8F5Y',
#  'fWcSBWadolA',
#  'YyhKdOCwD7s',
#  'ha4tRQwKIUg',
#  'xRwy_rKc7gI',
#  'H1WBdh56Vq4',
#  'xhIYirjB4Yc',
#  'HfJMs4mrSJM',
#  'tYHTVjfShOA',
#  'JTQcIR2ZxU4',
#  'xpNeg0hPZIs',
#  '9yrdFAJUSaU',
#  'i2O6GMpNWGo',
#  'Y6jC6VaO3j0',
#  'Ooke4YZv8Ts',
#  'ZV7rU6lnAKQ',
#  'iUzi5JmJNWc',
#  '9cCpZl8euLI',
#  'I046_n20d3s',
#  '2nd73lyvq4w',
#  'nuM0Z4a7kMs',
#  'qPBtTPJHS0Q',
#  'A-vX1AGBGsc',
#  'IiW2smvEcBM',
#  'q6Qw8mUVTrE',
#  'dBxOYE2j55U',
#  '984NGLLYDUg',
#  '7zi0bi-RDj4',
#  'XaxhLbxZ13k',
#  'L8nh1wuXTbI',
#  '9-HphHIJS9c',
#  'rPXmbM2UEbU',
#  'sESRuTyfsEk',
#  'QapO3maXd9k',
#  '71VpdDb8e6U',
#  'Su34c5Z8DW4',
#  'e5DqdX-7_g4',
#  '9vB-48kHbBU',
#  '3ix_gbcubTo',
#  'mGIpOtncmSM',
#  'VqnQ-0q2gb4',
#  '3TflpIllQHY',
#  '1SwVSTKFCsc',
#  'ZPuEUe_8SRM',
#  'gKVZz4kcuns',
#  'nywT2SenPIo',
#  'xBP9EUQIkNs',
#  'qZNxvnQv0h4',
#  'uE6gud1voDs',
#  'f0M64XpmTz8',
#  'Gz3yak1cl-8',
#  '9GD6hbqu2oM',
#  'GUWGsIVEMSQ',
#  'wDqJZ_2ZA3A',
#  'RywkkwO78m8',
#  'P4qWhSZ7_WA',
#  'UlUcwJc5nBs',
#  'qAW6CE7_bFM',
#  'tBEBc4KQVsU',
#  'q0OK-zHnvnA',
#  'bFZdU9dr4OM',
#  'nd-bwvNB7YA',
#  '6_im_hGxGRk',
#  'b91vrgVY-ZQ',
#  '52ubXjlVzUY',
#  'XHb7g6yuGgE',
#  'rH1D_3G56DY',
#  '-0zoWMSEOGg',
#  'WRzIuC2MKOU',
#  'foLlul8Tl3E',
#  '3iaDrpKdaIc',
#  'qrIh-ZHN4-E',
#  'mpZWt5pGKZ8',
#  'vbph9F_pRNI',
#  'XE9pUM9MEFA',
#  'wbzD04leeLI',
#  'MC5h-ShR-S8',
#  'dp8IaLrZpGs',
#  '97Gh93Daio0',
#  't4OumncEiKo',
#  'Ejou8aa5eZk',
#  'ehEuczQUh8E',
#  'uBC7805Smsg',
#  'd8pJkuSp1iI',
#  'dFr5YQaQQdo',
#  'xBLxMfO3pDw',
#  'd7QmQtNwhcU',
#  'NZR4WEjpOQg',
#  'vETSAZgfDP4',
#  'zE3FLbpu9-Q',
#  'Izmibu7dxcs',
#  '2Pvt8awds44',
#  'n9BbAfbsyj0',
#  'WZ2rYlVxt4g',
#  'CWK6an4mYL0',
#  'VwWV4JelEzY',
#  'koRKIlRQj4g',
#  'XKFKPQHdWRI',
#  'yuGEB4ZZdUQ',
#  'sg_XFT4K3N4',
#  'szt8xabJoSo',
#  'Fbl3E_XCQfA',
#  'Pe3pGsCeYXg',
#  'yzGmnjDFuZE',
#  'op0N7axawJA',
#  'l_huIWJBhJM',
#  '7ALCsEyn3mg',
#  'CvMRiR4k49Y',
#  'g2rbhIB-ITM',
#  'nLpqZEAFnkE',
#  'sirrTXiPFmw',
#  'nRkwuTOESCc',
#  'AS6WMS_Bemg',
#  'wMn8d7IeCYM',
#  'BMZP4CtphaU',
#  'ln9aLVd__8w',
#  '93s1JECSy60',
#  'YR6Wh2Zy9jE',
#  '5PCxQSMOl3o',
#  '5qzAVMe_SnM',
#  'zAAXW7ySu1k',
#  'sx5k8xd_VoU',
#  'uotb9ZHnI2g',
#  'nPlqRbVFBHI',
#  '_FX6rml2Yjs',
#  'kupaqq-xJ_8',
#  'Er6QUQZbv0w',
#  '4KVmSG6KS2k',
#  'Lx9fRu5ehFo',
#  'KcsRxHwGz7A',
#  'ZJwX2jTXWwQ',
#  'N_GMakKf7G4',
#  '63gyUQ_JeOE',
#  'IZVbzNRUlQI',
#  '8D3vI1615K4',
#  'igVcy5dtN80',
#  'dEOlvTqYUNo',
#  'AS5CxLCWq-Q',
#  'jtOalDNVrKM',
#  'dDYP56hEYF0',
#  'pJSbLk-Iixc',
#  'iengNekeTNo',
#  'rqUvnLPvbrM',
#  '9CVwXBYVqVk',
#  'i8pmk5xnO2s',
#  'xWcldHxHFpo',
#  'YH1-fDzHHpo',
#  'ntlG5XgYg4k',
#  'Qy17S3g8ZuY',
#  'PJyWmlWNor8',
#  'KzwTYZ2W3ZA',
#  '9fa_JYTPZ2Y',
#  't1BWMa8btIw',
#  '2O8wta4FsD4',
#  'dSDBr0WjrwQ',
#  'DbC9CauTXoM',
#  'yhNcDBnQsEY',
#  'Wyyqz3OxB5c',
#  'KO8B2kw_Jxs',
#  'NEDPgQYhbqs',
#  'DpIvW6av0pI',
#  'RPcXg2-0ejw',
#  'jhYG5BStQSk',
#  'wTIPpjUgAFE',
#  'Fzh65vCyHWQ',
#  'vBp0bzVr09s',
#  'AXjdI_LHWJU',
#  'dJCsc_Cq9i4',
#  'bqpKlkPpT10',
#  'TIIU1ivhLKs',
#  'G4qOiwIE_o0',
#  'yozl6enFC-w',
#  'LP_mGU3CgXk',
#  'DoIQMkoYSzw',
#  'e-If_d_bzfI',
#  '5J6-5g2alp8',
#  'qjGNBluF6_I',
#  'TLoDwqQF5ug',
#  'uAFGIQPWL54',
#  'SaDDjW9Rw-M',
#  'CHdy9wND1jo',
#  '9LiS_3HEErU',
#  'hRj5qNfkdO0',
#  'ocruJKe2tFk',
#  'MgRMNzKknto',
#  'tqO3_AKC5Ks',
#  'XW1TsAVdXsw',
#  'Qhdj_Umh1IE',
#  'fN_RQFqaGHI',
#  'hC3xW8xeCDs',
#  'xGJEPTCw9GU',
#  'FmjsePPBbdU',
#  'lMLEcUXz6T8',
#  'BKJy7BFP3Is',
#  '1gfgZhW3YgU',
#  'VXmKt_1T0QM',
#  '6XCUHLhdnEY',
#  'ttWTSskmxTA',
#  '5bCyFf8lSfk',
#  'ngVEpJs5A5s',
#  'zjC48c3ptt0',
#  'rS2sntC-lJI',
#  'fG1N5kzeAhM',
#  'vT_gRRMjDi0',
#  'dfcPUqiivDY',
#  'zCR6DJX7Kak',
#  '4cX-w-ia0RU',
#  '2nVjy-zd65Q',
#  'xlzpD4GeBW0',
#  '8ZTy3K2QgOY',
#  'k9zko79_3_I',
#  'fYnPyLfxSJg',
#  'pBH_QL4JGcI',
#  '1wtFD9zSQO8',
#  'VqhjiwmGNKA',
#  'EhZ9gHZOZT8',
#  'LHtkve6-O0g',
#  'm3Ol8zn7brk',
#  'qBiZA4QDsj0',
#  'NeOrh4GnPZ4',
#  'fWhfOAuOqjY',
#  '9Ax56oRhcZc',
#  '-cWVrFABWHw',
#  'z7qtJAAV5d0',
#  '9pk-neTrDoM',
#  'JQscW6DfNZY',
#  '9smE_EiKJ8Q',
#  'hfaPkoXeYfU',
#  'u0hHxeWkB_o',
#  '64WGWubQO3I',
#  'QJUs6CSRCFU',
#  'Om4c4ilT_6g',
#  'GbOfxRfHdeg',
#  'yzxYCRDcGDs',
#  'PCakYf_PnT0',
#  '8nv_ltg4RAg',
#  'VvphlSvCyj8',
#  'JP3v6UxI124',
#  'jRURlbRAUhI',
#  'I_3R9YGFlHE',
#  'xjJJ_wDlc1E',
#  'cqirhwhq_qM',
#  '3IQdDBwc42o',
#  '4YHnf3YepwU',
#  'uxzBq4Y_fNw',
#  'HIhUkvAG0o4',
#  'cpI5lCaqZcQ',
#  '6zQhLOw1nw8',
#  'mfvi_jgdVqE',
#  'zExxMxcoJ6A',
#  'hD_Af6W2qug',
#  'XOtTKQujlkI',
#  'dRqthQ2Mc_0',
#  '8TFq_vvO_Wg',
#  'oo8ve4Ldpck',
#  'sKn8Tbp2a-4',
#  'g0IrVKXIbmE',
#  '2Om2M4_Kyd0',
#  'KaaEivIqX6M',
#  'W4gBpws7Ug8',
#  'NT3EkjxO8hs',
#  'syMozMiJneM',
#  'Wt6cMjn3YLg',
#  'OEuS7fjMlMc',
#  '1Pr-R2nKTY4',
#  'QqdUhn99E-s',
#  '1UygJmcHUdQ',
#  'g4DAFnZcCcQ',
#  'LTr8cXAxy1I',
#  'Ow3xqv7ahXo',
#  'TRiF8PdrIP8',
#  'NFZ_MtTvwm0',
#  'Pgxi8dsUW-o',
#  'YY2-jJojnOA',
#  '7Pogam71094',
#  'DL0OPJ2hahc',
#  'WwE0tR08OTU',
#  '2LIJtcI4dbg',
#  'rXnaD7PU9kY',
#  'Ng_qwlvhrJo',
#  'bzIPun3cVsw',
#  'miKQkeq5sbU',
#  'Lwt_VThQIdM',
#  'P2oPACr4uuU',
#  'h-D6ukDcS9o',
#  'mY77HA20MzA',
#  '4krBgDFycgY',
#  'dpUxRIqbNlc',
#  'Cp431S5z8PE',
#  'ttLYXcza4j4',
#  '3-f9DEFsh4w',
#  'vuOTP206zWM',
#  'J590MYm0SY8',
#  'vGB2d5cQJpY',
#  'M94G0iKYiSM',
#  'pGYyUssWLTA',
#  'j7kM8G_AjuY',
#  'deK-My3Of0o',
#  'oB8kFFvJdhE',
#  'X9eXa-Uzuj0',
#  'GxTVDClFXuc',
#  'kGaq-Qi9hoE',
#  '9zFfp3gzZ88',
#  'mM2KwBYa-u4',
#  'WAcmsAISniQ',
#  'kqUT-s3a6tU',
#  'NUVglXbGBfs',
#  'T-v4b3WtPAg',
#  'm8qGlpcfAIw',
#  'afL8tYlnrj4',
#  'uZPkMnv8b-o',
#  'qVLr6SMxvJw',
#  '4AigP5OY8JE',
#  'RMoFUeBVefA',
#  'ep7S1XnuQLU',
#  'p6bzNpgbX8Y',
#  '6T17licWsQ4',
#  '1s6UOlWdpw4',
#  '3LuchpUc7PU',
#  '_f6xCA0-gAo',
#  'lfD7kMZKuNg',
#  'ejlkNGm82w4',
#  'Jtj9rUqlB1Y',
#  'ZqzFRGH_tMQ',
#  '94A-bsumX9A',
#  'gYaxI_allkQ',
#  'AjXbO2XfBkE',
#  'ZQZzR0DUujc',
#  '-V3-fhJQZkk',
#  'QX0wvWGW2qg',
#  'oODUkNQAzXU',
#  '2jWZtKTN6jU',
#  'zsADECFHY8w',
#  'Feh8o-HmthM',
#  '6Xv-LVYZQxk',
#  '8-0ZHJHp9g4',
#  'QqIG0R-KpGk',
#  'qENpZBzgaUM',
#  '4DYBVA4884Y',
#  'skEf9R0TXkM',
#  'CnMv_zTXZ38',
#  'bEIK5ni_Pzs',
#  '_oZyp4mTzSQ',
#  'is1LSWbssuA',
#  'XR_q9_LEKuc',
#  'X9UiBpDHW3w',
#  'PRU47AuQF2M',
#  'Y3Rxgf5_R_I',
#  'R6zuvKbvKyU',
#  'yCKe65Nvp0Q',
#  'XBe57FyB2xU',
#  'zpCwHwWgbsI',
#  'lh61MVUxJt0',
#  'yWnmEPgLroQ',
#  'eBklqeeIu10',
#  'SgMydsOucFg',
#  'jPm3hRiMKuU',
#  'OweuuinkVZI',
#  '7Pr0HP-Trgk',
#  'UEK0fYAqMss',
#  'lRznKN2oPUc',
#  'IDrS_TrjuK4',
#  'J1lhxfZtR3M',
#  'b_o8cz0ZNdk',
#  'i5dhcAxO25Q',
#  '-o_8CDbFMJ0',
#  'v5J1Cycn3s8',
#  'YJiqYG-Mylk',
#  'jGE1sUTeR5g',
#  '0tZCQ25fsoI',
#  'N9jTogPwqVY',
#  'yyJ7xEcENNI',
#  '3rJgCGMPEqA',
#  '7isfkomGg7o',
#  'UCYefSGBP00',
#  'dvdGkRK5a_0',
#  'X7doE4h6W64',
#  'GhppzOzN3MM',
#  'QkXDatNdL4U',
#  'hyt2t4r8lQ4',
#  '-mlok5iT3GE',
#  'STvOHHgJ1sQ',
#  '2-ErX5oDzwM',
#  '7ytYV-tVIvg',
#  'ELIoOUKSOJQ',
#  'uAoayezOaug',
#  'Vr2337tCLCI',
#  'NV7qmqbS8tM',
#  'U9c-ycvw02A',
#  'GfgcVOuHLAo',
#  'zi7tZ-2PhLk',
#  'TacjQmKCiZg',
#  'AIytwdufwW8',
#  'KLAI0c0Spog',
#  'UVin8WtE5eU',
#  'wNuxirsrwBk',
#  '6bxZpS0cm5o',
#  'ajJbMGq9AS4',
#  'UXw9jqgJNNc',
#  'E3CqKvlzl-I',
#  'zfDr05ax0gM',
#  '56OkH6ocYZU',
#  'w40Z8aT5fpQ',
#  'zgDezsMQyyU',
#  'UEwnitHoSDw',
#  '__SaaKSW9iE',
#  'qWnyJ55KBKo',
#  '52awie9G00A',
#  'bB99NdUoxEQ',
#  '7GjSaNi8Epg',
#  'h5uE4ERMiTk',
#  'umRLkCrmwcs',
#  'rHoLyltYDtQ',
#  'yeHjsYQ076A',
#  'pqrdPu2ESFo',
#  'ywZy_Fo2ydo',
#  'qr4v9pdfVlU',
#  'hgiPX33AHas',
#  'oZ-Mn5p1xMw',
#  '5UPa_hu5opg',
#  'zv_oq5UNDAo',
#  'NiqkH7qVW0U',
#  'boBokLXe5o8',
#  '7YOzgk-U4EU',
#  'prdSftLj9-g',
#  'pzlPJmNyepA',
#  'QNoqAnJOSqU',
#  'kzIA4vKyhRQ',
#  'DfonKqMENrg',
#  'MUQCwdkEbq0',
#  'JlUzoQN9FWw',
#  '0VjLq-go1fg',
#  'uCIpW9zOmgI',
#  'Z0Poefgrs4w',
#  'MLN6TRB9Jxw',
#  'vZrL_FFITgs',
#  'L7lGD_anC00',
#  'xu1nhAfnMGA',
#  'D1livXdFGkQ',
#  'bwp_3qLgWpQ',
#  'tZpnfF0-7Ls',
#  'BwAMltY3-c0',
#  '7HBR3Ea72CY',
#  'Ds9H2UnUHL0',
#  'iqUFeWAVp-0',
#  'W2skFWRk6qo',
#  'X_qd-1xSTFA',
#  'VWa0ImMY2bQ',
#  'fEcASr38n2E',
#  'udmf5MQLNGA',
#  '0dg2eR2NSQ0',
#  '6BNOWeYFyP8',
#  'LDegY-H60_U',
#  'D51HaR-XvgM',
#  'Rio7r_vLUEo',
#  '8E5Ygl02wtM',
#  'moMJjt5KECc',
#  'OffgqPzDi7Q',
#  'B_7uD3B62MM',
#  'bA20RJcegOI',
#  'NbHwVDt9Rjk',
#  'VzsE09KjpKA',
#  'HduubRTdko4',
#  'qFOGv5zuTdw',
#  'u6t4jrhs56Q',
#  '460GXJiGCEs',
#  'ZiuoOcj2eLY',
#  'LYK6SPMtJ_Y',
#  '2ljWxaMvE_0',
#  'rSuuQ_s8gOw',
#  'vKKhX-Uyggw',
#  'EAwXH82m-6A',
#  'U_07AG_CR5A',
#  'Xe0AGtF5aNU',
#  'NCv0drAPm_M',
#  'HuLAAXZXIy0',
#  'pV7UcYW1OwA',
#  'x4IXCimma-s',
#  'anZbhN0Wh_4',
#  '3Q3pQmzWyZM',
#  'BqS4iVHa-LU',
#  'zX04jQFKCpo',
#  'G7Y9ban7b0U',
#  'EMVvA5Cr0fY',
#  'e14MroQ5k_s',
#  'CuzdxsOXEZ8',
#  '67Wj-0OyKOM',
#  'LWstCINhd8g',
#  'dg6iqLCPizs',
#  'cRPldarzw-M',
#  '-rdYtmUejSE',
#  'tusuuI7MEJU',
#  'XDe5f8BEvwY',
#  'BtCGABBPH9s',
#  'KJ_C_NSl0P8',
#  'LI8nWXeYtOs',
#  'LMe7k8I082w',
#  'h77pHTSPSiw',
#  'JUiijjJOInw',
#  'gpbY6zCEBv4',
#  'Kgu2ApayYvI',
#  'S9PIukDRcvk',
#  'lrw3zkGS9Vc',
#  'IQYW_lVBYGo',
#  'iOjxpow6jow',
#  'GdD2pqAdjXY',
#  'nmHCmLVLxcU',
#  'TZPlDuYrcDQ',
#  'Oub4nMrNTqQ',
#  'h5Z36IuyrKc',
#  '2IGxSOfsBok',
#  'ZxkLCq49Tvk',
#  'smDPnIdlkhM',
#  'DjMYkWCEan8',
#  '3nn_skHgkqI',
#  'A8IkOqb_7Yg',
#  'hHl_YMivv3c',
#  '7mLSbgyjM0g',
#  'TGKkMl17Htg',
#  'Qw3eFnsSdlQ',
#  'KcNCJ1mgt14',
#  'A4lp4FRCo6o',
#  'WYKZz3Zygdc',
#  '5U2fmvh9_Is',
#  'xvIpibLjs5k',
#  'jlpAON0ePME',
#  'sfp0a6zDoNQ',
#  'RaDRWNz3Al4',
#  'Ms9MGkEm4mg',
#  '90wWStXJX5c',
#  'ruSVy-u2DzM',
#  'pP1KMQb51GA',
#  'dPxAFqs2eYE',
#  'p-KVD5rA_Cw',
#  'JdCgkcb1iwQ',
#  '7anhkLPRk-A',
#  'XVMY7B3AzWM',
#  'QXag-irFHxE',
#  'vBEGODNmdas',
#  'v3tbnlc5cfo',
#  'ObYLL97-SBA',
#  'IaR7P4-wFK8',
#  'v1ELS84GQu8',
#  'ctJORnOjbrQ',
#  '-hrPQFaDVKQ',
#  'bIZ5_L1ru2w',
#  'yyssjJEJMt4',
#  '2bwPntvb90U',
#  'Wz1VHTZq16c',
#  'Cs-kyTJso-A',
#  'jkqd-oc0F00',
#  'mVkT6Cd9SoI',
#  'rffyxTTNkyk',
#  'OOesLeO6-pc',
#  'Q5lcjP6XlHw',
#  'sE3ZZmYotSs',
#  'pUwUAtmBKxw',
#  'p5rGgPZtjDw',
#  'bWDmDsdvoBs',
#  'OJA1QK-j-Oo',
#  'KL1X8NsVGd0',
#  'q2HoSwCMcZw',
#  'RRknlgRqOds',
#  'j93M46a-W3U',
#  'uqjfMNEWNIg',
#  'X-g9aT2wFjM',
#  'pHKlrJeKmjA',
#  'C82suucz4i4',
#  'H_DYlka7QAQ',
#  'ov0KQthQ50U',
#  'MC-7ziNt_U4',
#  'PNsF1Uh5yP8',
#  '9Y2sAtN5yRs',
#  '-z349CGAOXs',
#  'pl4xmh3RWfE',
#  '6z5RwrvnH28',
#  'ivdQqobHDPc',
#  'uUIlb2rpIuY',
#  'Ros1PpcO5Js',
#  'KYv1nqutbK0',
#  '7Yi-ctyTNU4',
#  'VN2-3OfUzd8',
#  '-2IFrMOM36w',
#  '7dIFHQkrASM',
#  'QicO1Gd0kvU',
#  'yFfcsmK2TOA',
#  'Jl0-6tbNGBo',
#  'IAbX0FwX-GY',
#  'XKSJRulqDNA',
#  'jysfHFHNjYQ',
#  'Yox25V8Qsm4',
#  'clcN3OA8SNw',
#  'm3lTwO0aNyw',
#  'gchqnwXlxJw',
#  'atCPtw4dg7g',
#  't8aM4HuVLrQ',
#  'M82VAcabSiA',
#  '7qj3nuF9Dzw',
#  'Y74b7WlcEpk',
#  'Z8nEEdXTaX0',
#  'jP82d277Cc8',
#  '2XVcLrB7B3Y',
#  'tTPig-b8jrE',
#  '55JeiGjdank',
#  'rWDcdl8SFAI',
#  'gi3tOjDeMVY',
#  'i9ay8ddOqX0',
#  'uZy2Lwioi3g',
#  'EB8lfdxpirM',
#  'z8867JgHKug',
#  'ragDjDfwWGM',
#  'dKr1o0tShNM',
#  'aq68N-FH1yY',
#  '5L0oyrwiNNE',
#  '9cKuk5ZkY3I',
#  'i7DWNXmpdF0',
#  '9MlZW9QeLM8',
#  'WxWRXNna1Qw',
#  'avdPRFopLNw',
#  'D18G7hW8418',
#  'ztqTIGBZXAA',
#  't3_5fHU5HXs',
#  'SnBJGesQMK4',
#  'ECgnw6yOSL8',
#  'mB3yklnDsbw',
#  'wwn3BNTYzkU',
#  'sVNvAtIZWdQ',
#  '_TTYPLR1VeY',
#  'MO-a-5G_ZAI',
#  'fG8N2PhoACk',
#  'J17YrAvZzqg',
#  'hctDUJTqCOU',
#  'U22ADs08XAY',
#  'dSzKCRHrqoo',
#  '5QxqqeOxJhI',
#  'ZPydLuauxnU',
#  'K9AnJ9_ZAXE',
#  'rcG4WNwi900',
#  'vuxrhipJMCk',
#  '0UepvC9X4HY',
#  'S1eapG6gjLU',
#  'tpuovQFUByk',
#  'OXOiUeHOQ-0',
#  '9y0mqWsok_4',
#  'IumQX-mm20Y',
#  'CLkzXrjrFKg',
#  'UFsCvWjQT4w',
#  'mtJHMdoi_Gg',
#  'J6azvFhndLg',
#  'z7xyNOF8tak',
#  'YZSv1Q8zuWo',
#  'njzjxMftEe8',
#  'hmxfn4cTdlQ',
#  'iXVGrwRxV2c',
#  'vW_LAxHJY_w',
#  'ZBVm07ywKoY',
#  'EMCNElHeamE',
#  '5OETMN8YU_A',
#  'tT46slhGCFA',
#  ...]

# %%
def get_video_details(youtube, video_ids):    
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
videoDetails=get_video_details(youtube, Video_ids)
videoDetails
# Out:
#          video_id       channelTitle  \
# 0     r_K9hznoPKU     Darshil Parmar
# 1     0iNJPKheQqM     Darshil Parmar
# 2     XnPF-MDMUzc     Darshil Parmar
# 3     V7ue-tM2aYU     Darshil Parmar
# 4     KV4hZR5-D-4     Darshil Parmar
# ...           ...                ...
# 2767  TRM_e1O7TVU  Rohit & Kanupriya
# 2768  U_xZFqXOyFY  Rohit & Kanupriya
# 2769  k7dmrSbCpy4  Rohit & Kanupriya
# 2770  cffqyq-U2Og  Rohit & Kanupriya
# 2771  xxwNglca0Bo  Rohit & Kanupriya
#
#                                                   title  \
# 0     The State of Data Engineering in 2024 - Jobs, ...
# 1     IPL Data Analysis | Apache Spark End-To-End Da...
# 2     You're not stupid: How to learn difficult thin...
# 3     Best Apache Spark Course with Databricks for D...
# 4           How I Got 60LPA Remote Job as Data Engineer
# ...                                                 ...
# 2767              The problem with ordering food online
# 2768                          This break up didn't hurt
# 2769           My daily routine a.k.a The Vicious Cycle
# 2770                          Every group has THIS guy.
# 2771         Limca Book of World Records - Renu Sukheja
#
#                                             description  \
# 0     Combo Package Python + SQL + Data warehouse (S...
# 1     Enroll in the Apache Spark Course Here - https...
# 2     Enroll in the Apache Spark Course Here - https...
# 3     Enroll in the Apache Spark Course Here - https...
# 4     Join My Data Engineering Course Here: https://...
# ...                                                 ...
# 2767
# 2768      Another one from the 'me annoying me' series.
# 2769  My daily routine. How I wish I could somehow t...
# 2770  Every group has this annoying person. The one ...
# 2771  In 2011, Mrs. Renu Sukheja at the age of 50, b...
#
#                                                    tags           publishedAt  \
# 0     [The State of Data Engineering in 2024, data e...  2024-05-12T13:00:51Z
# 1     [darshil parmar, data engineer interview tips,...  2024-04-21T13:30:00Z
# 2     [darshil parmar, data engineering, how to lear...  2024-04-14T13:10:17Z
# 3     [darshil parmar, data engineering projects for...  2024-03-31T13:00:21Z
# 4     [darshil parmar data engineer project, data en...  2024-03-11T15:22:46Z
# ...                                                 ...                   ...
# 2767  [food delivery, ordering food, ordering food o...  2021-05-30T16:49:42Z
# 2768  [Funny, tiktok, funny videos, Instagram reels,...  2021-05-26T15:37:56Z
# 2769  [anxiety, motivation, netflix, daily routine, ...  2021-05-19T20:29:25Z
# 2770  [Questions, friend, what would you do, annoyin...  2021-05-19T20:26:16Z
# 2771                                    [Limca (Brand)]  2013-05-06T18:57:41Z
#
#      viewCount likeCount favouriteCount commentCount    duration definition  \
# 0        19221       454           None           55    PT15M42S         hd
# 1        36689      1238           None           95  PT1H19M53S         hd
# 2        19261       583           None           44    PT23M56S         hd
# 3        16681       418           None           73    PT12M39S         hd
# 4       107354      2806           None          104    PT10M23S         hd
# ...        ...       ...            ...          ...         ...        ...
# 2767   6691373    214654           None         1214       PT21S         hd
# 2768    498978     15506           None           58       PT13S         hd
# 2769    205505     10572           None           89       PT31S         hd
# 2770    207677      3098           None           43     PT1M20S         hd
# 2771    149220      1073           None           68    PT10M18S         hd
#
#      caption
# 0       true
# 1      false
# 2       true
# 3       true
# 4       true
# ...      ...
# 2767   false
# 2768   false
# 2769   false
# 2770   false
# 2771   false
#
# [2772 rows x 13 columns]

# %%
videoDetails.to_csv('Data\\apiData.csv', index=False)
